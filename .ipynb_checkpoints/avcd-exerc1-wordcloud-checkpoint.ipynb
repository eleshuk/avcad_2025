# %% [markdown]
# # Analysis and Visualization of Complex Data
# ---
# ## Exercise 01 - Creating a word cloud in Python
#
# In this exercise you will produce your personal word cloud using python
#
# First we will need to install Wordcloud package (someone already did the most difficult job - a function that produces a word cloud - so let's take advantage of that!). Go to the terminal and:
#
# ```
# $ git clone https://github.com/amueller/word_cloud.git
# $ cd word_cloud
# $ pip install .
# ```
#
# Or more simply:
# ```
# $ git install wordcloud
# ```
#
# Import required packages

# %%
import pandas as pd
import numpy as np
import os # provides functions for interacting with the operating system
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Let us first use an example from a Wine review database from www.Kaggle.com, named ["Wine Reviews"](https://www.kaggle.com/zynicide/wine-reviews/data). You can find the csv dataset in the class [github repository](https://github.com/isa-ulisboa/greends-avcd/tree/main/Examples)
#
# You may clone it to your local machine.
#
# First check your current directory:

# %%
os.getcwd()
# Out:
# '/Users/eleshuk/Documents/GitHub/avcad_2025'

# %% [markdown]
# You may change the directory to which you want to clone the github repository (change path accordingly):

# %%
os.chdir("/Users/eleshuk/Documents/GitHub/avcad_2025/")
os.getcwd()
# Out:
# '/Users/eleshuk/Documents/GitHub/avcad_2025'

# %% [markdown]
# Now you clone the github repository to your local machine:
#
# ```
# $ git clone https://github.com/isa-ulisboa/greends-avcd-2024.git
# ```
#
# Now you can import the wine review dataset:

# %%
df = pd.read_csv("examples/winemag-data-130k-v2.csv", index_col=0)

# %% [markdown]
# Check table (first 5 rows):

# %%
df.head()

# %% [markdown]
# Table summary:

# %%
print("There are {} observations and {} features in this dataset. \n".format(df.shape[0],df.shape[1]))
# Out:
# There are 129971 observations and 13 features in this dataset.

# %% [markdown]
# Check only part of the table ("country", "description" and "points")

# %%
df[["country", "description","points"]].head()

# %% [markdown]
# Now let us run the wordcloud function with the imported data.
#
# First it might be helpfull to get some info about wordcloud package:

# %%
# ?WordCloud

# %% [markdown]
# Combine all wine reviews into one big text and create a big fat cloud to see which characteristics are most common in these wines.

# %%
text = " ".join(review for review in df.description)
print ("There are {} words in the combination of all review.".format(len(text)))

# %% [markdown]
# Create stopword list (words that you don't want to include - make a test first and choose words accordingly):

# %%
stopwords = set(STOPWORDS)
stopwords.update(["drink", "now", "wine", "flavor", "flavors"])

# %% [markdown]
# Generate and display a word cloud image

# %%
wordcloud = WordCloud(max_font_size=100, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# NOTE: You've probably noticed the argument interpolation="bilinear" in the plt.imshow(). This is to make the displayed image appear more smoothly. For more information about the choice, here is a helpful link to explore more about this choice.

# %% [markdown]
# # Create your personal word cloud

# %% [markdown]
# In this exercise you will adapt the code below using the keywords that best describe your interests. For that you may use the text from your CV, a motivation letter or simply a list keywords. First create and save a txt file (no commas or semicolons) containing your text.
#
# I used a text file with a list of my publications (Note: the text was converted to csv and all punctuation marks were converted to "space".

# %%
from pdfminer.high_level import extract_text

def pdf_to_txt(pdf_path, txt_path):
    """Extract text from PDF while preserving spaces."""
    text = extract_text(pdf_path)  # pdfminer extracts with proper spacing
    
    with open(txt_path, "w", encoding="utf-8") as txt_file:
        txt_file.write(text)

pdf_to_txt("/Users/eleshuk/Documents/Resume and CV/E_Leshuk_CV.pdf", "/Users/eleshuk/Documents/Resume and CV/E_Leshuk_CV.txt")

# %%
text = open("/Users/eleshuk/Documents/Resume and CV/E_Leshuk_CV.txt").read()
print(text)
# Out:
# ELIZABETH LESHUK
#
# CONTACT
#
# PROFILE
#
# +1 530-902-6857
# eleshuk@gmail.com
# linkedin.com/in/eleshuk
#
# Hard-working, versatile environmental scientist with professional experience in
# agriculture technology, and professional training in data analytics and
# visualization. Key interests and background include sustainable agriculture, data
# science, environmental awareness, and ethical sourcing and fair trade.
#
# EDUCATION
# B.A. Environmental Studies
# June 2018
# University of California, Santa
# Barbara
# Santa Barbara, CA
#
# Certificate in Data Analytics and
# Visualization
# April 2021
# UC Berkeley Extension
#
# EXPERIENCE
#
# Anu (Heliponix, LLC.) | Evansville, IN
# PLANT, DATA, AND ENVIRONMENTAL SCIENTIST 2 • JUNE 2023—PRESENT
# PLANT, DATA, AND ENVIRONMENTAL SCIENTIST 1 • JUNE 2022—JUNE 2023
#
# Working at the intersection of sustainability, plant science, and data science to
# help develop environmentally friendly, in-home plant-growing devices.
# Responsibilities include:
#
# -
#
# Data collection, management, visualization, and analysis.
#
# -
#
# Tools: R, Snowflake
#
# KEY SKILLS
# -
#
# Strong foreign language
# skills
# R programming
# Data collection
# Interpersonal
# communication
# Learning mindset
# Attention to detail
#
# -
# -
# -
#
# -
# -
#
# ACTIVITIES AND INTERESTS
#
# -
# -
# -
# -
# -
#
# Reading
# Fitness
# Playing team sports
# International travel
# Playing music
#
# Leading student intern teams working on sustainability-oriented projects.
# Developing sustainability white papers.
#
# -
# -
# - Managing plant growth experiments.
# -
#
# Grant writing.
#
# BioConsortia, Inc. | Davis, CA
# RESEARCH ASSOCIATE 2/GREENHOUSE SUPERVISOR • MARCH 2021—MAY 2022
#
# Responsible for supervising day-to-day greenhouse operations.
# Created and managed R Shiny app for greenhouse data visualization.
# Responsible for maintaining root image analysis pipeline.
# Developed code for quality controlling and analyzing greenhouse data.
# Received excellence award for achievements in this position.
#
# -
# -
# -
# -
# -
# - Maintained responsibilities under Research Associate 1 role described
#
# below.
#
# RESEARCH ASSOCIATE 1 • SEPTEMBER 2019—FEBRUARY 2021
#
# -
#
# -
#
# Responsible for greenhouse data collection, preprocessing, and
# management.
# Prepared experiment materials.
#
# Environmental data collection, analysis, and presentation.
# Built skills in R programming for data analysis.
#
# -
# -
# - Maintained responsibilities under Plant Care Associate role described
#
# below .
#
# PLANT CARE ASSOCIATE • JANUARY 2019—AUGUST 2019
#
# -
# -
#
# Acted as liaison between Plant Care Team and supervisors.
# Responsible for day-to-day greenhouse operation and week-to-week
# planning for the Plant Care Team.
# Operated cutting-edge plant phenotyping devices.
#
# -
# - Maintained responsibilities under Plant Care Technician role described
#
# below.
#
# PLANT CARE TECHNICIAN • SEPTEMBER 2018—DECEMBER 2018
#
# -
#
# -
#
# -
#
# Set up experiments for multiple product pipelines in a research
# greenhouse.
# Conducted plant phenotyping to determine the effects of microbial
# treatments on plants.
# Responsible for plant care in research greenhouse and trial plots.
#
# Sourced Well, LLC. | Davis, CA
# INTERN • JULY 2018—DECEMBER 2018
#
# -
#
# -
#
# Conducted market research for an early-stage startup focused on
# ethical and sustainable apparel sourcing.
# Initiated and maintained relationships with producers, brands, and
# certification organizations.
# - Managed social media accounts.
#
# UCSB CCBER | Santa Barbara, CA
# STUDENT WORKER • SEPTEMBER 2016—JANUARY 2018
#
# -
#
# -
# -
# -
#
# Aided in native plant restoration around various sites on the UC Santa
# Barbara Campus with the Cheadle Center for Biodiversity and Ecological
# Restoration.
# Processed seeds, propagated plants, and planted on site.
# Assisted with seed collection on restoration sites.
# Identified plant species and tended to plants on site.
#
# UCSB REEF | Santa Barbara, CA
# LEAD INTERN • JUNE 2015—JUNE 2018
#
# -
#
# Led classes of 10-200 K-12 students, educators, and the general public at
# the Research, Experience, and Education Facility at the University of
# California, Santa Barbara campus.
#
# -
#
# -
#
# Educated students about the local marine and coastal ecosystems and
# taught both in classroom settings and outdoors.
# Carried out animal husbandry tasks such as cleaning and feeding.
#
# OTHER PROJECTS
#
# Python API Challenge| github.com/eleshuk/python-api-challenge
# Developed a Python script to obtain data from the OpenWeatherMap API to
# create a model of weather around the world, then used the data to run a linear
# regression on relationships between cloudiness, wind speed, temperature, and
# humidity vs. latitude.
#
# One-Hot_Future| github.com/yuyhong23/One-Hot_Future
# Collaborated on a team project to analyze global CO2 emissions and their sources
# on a per-country basis, and explore temperature trends to predict how
# temperature will change over the next 50 years.
#
# California-Wildfires-and-Climate-Change|github.com/roborgain1/Califor
# nia-Wildfires-and-Climate-Change
# Key member of a team project that aimed to predict future California wildfire
# severity based on past wildfire activity using climate patterns and drought data.
# The goal of this project was to predict whether the effects of climate change
# would influence wildfire severity.
#
# TECHNICAL SKILLS
#
# Intermediate knowledge of the following:
#
# -
# -
# -
#
# Languages: R
# Data Manipulation & Visualization: Shiny, Tidyverse
# Other: Git Bash, Microsoft Office Suite
#
# Basic knowledge of the following:
#
# -
# -
#
# -
# -
#
# Languages: Python, JavaScript, HTML5, CSS
# Data Manipulation & Visualization: Pandas, Numpy, Matplotlib,
# BeautifulSoup
# Database: MongoDB, MySQL
# Other: Flask
#
# SKILLS AND ABILITIES
#
# -
#
# Experienced international traveler, comfortable working in cross-cultural
# environments.
# Native proficiency in English and Spanish.
#
# -
# - Working proficiency in Dutch, including 3 years living in The Netherlands
#
# and attending Dutch schools.
# Limited working proficiency in French, having studied for 5 years.
#
# -
#
# -
# -
# -
#
# Elementary proficiency in Italian.
# Strong communication skills.
# Ability to work well in teams or independently.

# %% [markdown]
# Create stopword list (words that you don't want to include - make a test first and choose words accordingly):

# %%
stopwords = set(STOPWORDS)
stopwords.update(["Change", "proficiency", "include", "CA", "UC", "Key", "JANUARY", "SKILLS", "student", "associate", "JUNE", "SEPTEMBER", "DECEMBER", "maintained", "responsible", "role described", "eleshuk", "LLC", "years", "day", "role described"])

# %% [markdown]
# #### Generate and display a word cloud image

# %%
# Generate a word cloud image
wordcloud1 = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# NOTE: You've probably noticed the argument interpolation="bilinear" in the plt.imshow(). This is to make the displayed image appear more smoothly. For more information about the choice, here is a helpful link to explore more about this choice.

# %% [markdown]
# Set max_font_size, change the maximum number of word and lighten the background:

# %%
wordcloud_white = WordCloud(stopwords=stopwords, max_font_size=70, background_color="white", width=600, height=400,).generate(text)
plt.figure()
plt.imshow(wordcloud_white, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Save the image in the img folder:

# %%
wordcloud_white.to_file("/Users/eleshuk/Documents/Resume and CV/wordcloud_white.png")

# %% [markdown]
# ## Plotting word clouds using shapes
#
# You may also choose to plot your keywords within a given shape (e.g. that are related with your interests).
#
# Firt import the "image" module of the Python Imaging Library (PIL):

# %%
from PIL import Image

# %% [markdown]
# Now you will need an image (e.g. in png format) in which the background has the value 255. Copy into your current directory. You may check it this way:

# %%
turtle_mask = np.array(Image.open("C:/Users/psegurado/Documents/Aulas/Mestrado_Data_Science/Aulas_AVCAD_2023/greends-avdc-exercises/turtle.png"))
turtle_mask

# %% [markdown]
# Check mask

# %%
turtle_mask = np.array(Image.open("C:/Users/psegurado/Documents/Aulas/Mestrado_Data_Science/Aulas_AVCAD_2023/greends-avdc-exercises/turtle.png"))
#turtle_mask[230:250, 240:250]
plt.imshow(turtle_mask)
plt.axis("off")
plt.show()

# %% [markdown]
# And finally you may create, export and print the wordcloud

# %%
wc = WordCloud(background_color="white",
                  max_words=1000, 
                  mask=turtle_mask,
                  stopwords=stopwords,
                  contour_width=2,
                  repeat=True,
                  max_font_size=50,
                  contour_color='grey')

# Generate a wordcloud
wc.generate(text)

# store to file
wc.to_file("turtle_wordcloud.png")

# show
plt.figure(figsize=[10,5])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Questions
# - The world cloud you just produced is based on how many variables?
#
# - Which is the type of each variable in your word cloud?

# %% [markdown]
# # References
# [Generating WordClouds in Python Tutorial](https://www.datacamp.com/tutorial/wordcloud-python)
#
# [Python Wordcloud Tutorial](https://python-course.eu/applications-python/python-wordcloud-tutorial.php)
#
# [How to create a word cloud in Python?](https://www.projectpro.io/recipes/create-word-cloud-python)
